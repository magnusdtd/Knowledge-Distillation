# %%
# !git clone https://github.com/magnusdtd/Knowledge-Distillation.git
# %cd Knowledge-Distillation

# %%
# !wget https://raw.githubusercontent.com/google-research/distilling-step-by-step/refs/heads/main/datasets.zip
# !unzip datasets.zip

# %%
# !uv sync

# %%
 # !uv run main.py --from_pretrained google/t5-v1_1-base \
    --dataset esnli \
    --model_type task_prefix \
    --label_type llm \
    --llm palm \
    --alpha 0.5 \
    --batch_size 8
